# %%
#Se importan las librerias necesarias
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#Primero se hace una exploración básica para observar la estructura de los datos de la simulación
data = pd.read_csv('testing_data.csv')
data.head()
# Out:
#       T       X_1       Y_1      Vx_1      Vy_1       X_2       Y_2      Vx_2  \
# 0  0.00  0.203048  0.205798  0.304845  0.579758  0.793807  0.801588 -0.619348
# 1  0.01  0.206097  0.211595  0.304845  0.579758  0.787613  0.803175 -0.619348
# 2  0.02  0.209145  0.217393  0.304845  0.579758  0.781420  0.804763 -0.619348
# 3  0.03  0.212194  0.223190  0.304845  0.579758  0.775226  0.806351 -0.619348
# 4  0.04  0.215242  0.228988  0.304845  0.579758  0.769033  0.807938 -0.619348
#
#        Vy_2       X_3       Y_3      Vx_3      Vy_3       X_4       Y_4  \
# 0  0.158766  0.809971  0.204978  0.997093  0.497849  0.192561  0.808472
# 1  0.158766  0.819942  0.209957  0.997093  0.497849  0.185123  0.816943
# 2  0.158766  0.829913  0.214935  0.997093  0.497849  0.177684  0.825415
# 3  0.158766  0.839884  0.219914  0.997093  0.497849  0.170245  0.833886
# 4  0.158766  0.849855  0.224892  0.997093  0.497849  0.162807  0.842358
#
#        Vx_4      Vy_4
# 0 -0.743864  0.847159
# ...

# %%
data.tail()
# Out:
#           T       X_1       Y_1      Vx_1      Vy_1       X_2       Y_2  \
# 4222  42.22  0.458637  0.571617  0.165698  0.504997  0.600620  0.308681
# 4223  42.23  0.460294  0.576667  0.165698  0.504997  0.594709  0.316049
# 4224  42.24  0.461950  0.581717  0.165698  0.504997  0.588797  0.323417
# 4225  42.25  0.463607  0.586767  0.165698  0.504997  0.582885  0.330785
# 4226  42.26  0.465264  0.591817  0.165698  0.504997  0.576973  0.338154
#
#           Vx_2      Vy_2       X_3       Y_3      Vx_3      Vy_3       X_4  \
# 4222 -0.591172  0.736818  0.823318  0.854329 -0.987383 -0.395525  0.290439
# 4223 -0.591172  0.736818  0.813444  0.850374 -0.987383 -0.395525  0.280243
# 4224 -0.591172  0.736818  0.803571  0.846418 -0.987383 -0.395525  0.270046
# 4225 -0.591172  0.736818  0.793697  0.842463 -0.987383 -0.395525  0.259850
# 4226 -0.591172  0.736818  0.783823  0.838508 -0.987383 -0.395525  0.249654
#
#            Y_4      Vx_4     Vy_4
# 4222  0.665526 -1.019639 -0.07082
# ...

# %%
#Con esta exploración nos damos cuentas que las posiciones tienen un label: "X_n" y "Y_n"

# %%
#Dado que solo nos interesan las posiciones del disco en el eje x:
x_positions = pd.concat([data['X_1'], data['X_2'], data['X_3'], data['X_4']])
#Basicamente "componemos" un solo array con todas las posiciones de todos los discos en el eje x

# %%
#Ahora podemos crear de forma sencilla el histograma:
plt.hist(x_positions,bins=30,color='blue',alpha=0.7)
plt.title('Histograma combinado de posiciones X')
plt.xlabel('Posición X')
plt.ylabel('Frecuencia')
plt.show()
